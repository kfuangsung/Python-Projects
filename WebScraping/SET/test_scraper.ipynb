# %%
import setwebscrape as scraper
from IPython.display import clear_output

# %%
scraper.get_symbols()
# Out:
# getting symbols: 100%|██████████████████████████| 27/27 [00:04<00:00,  5.65it/s]
# Saved to 'SET_symbols.json'

# %%
scraper.get_all_company_highlights()
# Out:
# getting company highlights: 100%|███████████████| 27/27 [02:28<00:00,  5.52s/it]
# Saved to 'SET_companyHighlights.json'

# %%
data = scraper.load_json('SET_companyHighlights.json')

# %%
symbol = 'AOT'
scraper.show_company_highlights(data[symbol])
# Out:
# *** AOT | FinancialData ***
#                                      Y/E '18 30/09/2018  Y/E '19 30/09/2019  \
# Assets                                        187708.55           198381.56
# Liabilities                                    43439.43            43842.92
# Equity                                        143902.78           153899.11
# Paid-up Capital                                14285.70            14285.70
# Revenue                                        61918.81            64384.75
# Profit (Loss) from Other Activities              217.12              182.04
# Net Profit                                     25170.76            25026.37
# EPS (Baht)                                         1.76                1.75
# ROA(%)                                            17.56               16.73
# ROE(%)                                            18.29               16.81
# Net Profit Margin(%)                              40.74               38.98
#
# ...

# %%
symbol = 'OR'
scraper.show_company_highlights(data[symbol])
# Out:
# *** OR | FinancialData ***
#                                      Y/E '19 31/12/2019  Y/E '20 31/12/2020  \
# Assets                                        152176.21           144979.30
# Liabilities                                   113468.38           107063.34
# Equity                                         38707.83            37823.44
# Paid-up Capital                                90000.00            90000.00
# Revenue                                       583208.75           432848.96
# Profit (Loss) from Other Activities              927.85              108.31
# Net Profit                                     10895.81             8791.07
# EPS (Baht)                                         1.21                0.98
# ROA(%)                                             9.59                8.09
# ROE(%)                                            28.15               22.97
# Net Profit Margin(%)                               1.87                2.03
#
# ...

# %%
symbol = 'DELTA'
scraper.show_company_highlights(data[symbol])
# Out:
# *** DELTA | FinancialData ***
#                                      Y/E '18 31/12/2018  Y/E '19 31/12/2019  \
# Assets                                         48200.69            45958.29
# Liabilities                                    14259.77            12951.94
# Equity                                         33936.50            33010.22
# Paid-up Capital                                 1247.38             1247.38
# Revenue                                        53708.01            51838.37
# Profit (Loss) from Other Activities              229.23               58.30
# Net Profit                                      5137.03             2959.96
# EPS (Baht)                                         4.12                2.37
# ROA(%)                                            11.33                6.31
# ROE(%)                                            15.47                8.84
# Net Profit Margin(%)                               9.55                5.69
#
# ...

# %%
import amazonwebscrape as scraper

# %%
scraper.books_web_scraping()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Saved file 'AmazonBestSellersBooks.json'
# Saved file 'AmazonBestSellersBooks.json'
# Total data: 100

# %%
data = scraper.load_json('AmazonBestSellersBooks.json')
len(data)
# Out:
# 100

# %%
scraper.show_books_results(data)
# Out:
# https://www.amazon.com//Goodnight-Moon-Margaret-Wise-Brown/dp/0694003611/ref=zg_bs_books_12/134-8990605-5329166?pd_rd_i=0694003611&psc=1
# Goodnight Moon
# Margaret Wise Brown
# 4.9 out of 5 stars | 21,895
# Board book
# $5.36
# --------------------------------------------------
# https://www.amazon.com//Survival-Medicine-Handbook-Essential-Guide/dp/0988872501/ref=zg_bs_books_29/134-8990605-5329166?pd_rd_i=0988872501&psc=1
# The Survival Medicine Handbook: The Essential Guide for When Help is NOT on the Way
# Joseph Alton MD
# 4.8 out of 5 stars | 695
# Paperback
# $33.99
# --------------------------------------------------
# https://www.amazon.com//Going-Bed-Book-Sandra-Boynton/dp/0671449028/ref=zg_bs_books_97/134-8990605-5329166?pd_rd_i=0671449028&psc=1
# The Going-To-Bed Book
# Sandra Boynton
# 4.8 out of 5 stars | 13,376
# Board book
# $3.59
# --------------------------------------------------
# ...

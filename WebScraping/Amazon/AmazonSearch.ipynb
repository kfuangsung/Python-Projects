# %%
import amazonwebscrape as scraper

# %%
KEYWORD = "shirt"
TOTAL_PAGES = 10

# %%
scraper.search_web_scraping(KEYWORD, TOTAL_PAGES)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# KEYWORD:shirt | PAGE:1 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:2 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:3 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:4 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:5 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:6 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:7 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:8 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:9 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# KEYWORD:shirt | PAGE:10 | SUCCESS
# Saved file 'AmazonSearch_shirt.json'
# Total data: 425

# %%
data = scraper.load_json(f'AmazonSearch_{KEYWORD}.json')
len(data)
# Out:
# 425

# %%
scraper.show_search_results(data, 10)
# Out:
# https://www.amazon.com/Lacoste-Sport-Raglan-Sleeve-XXX-Large/dp/B00R3VEU7S/ref=sr_1_106?keywords=shirt&qid=1643967720&sr=8-106
# Lacoste Men's Sport Short Ultra Dry Raglan Sleeve Polo Shirt
# 4.4 out of 5 stars | 986
# $79.99 | (None)
# --------------------------------------------------
# https://www.amazon.com/Unique-Baby-Valentines-Crusher-Raglan/dp/B09HBRFZG7/ref=sr_1_218?keywords=shirt&qid=1643967726&sr=8-218
# Unique Baby Boys Valentines Day Heart Crusher Raglan T Shirt
# None | None
# $22.99 | (None)
# --------------------------------------------------
# https://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_mtf_aps_sr_pg2_1?ie=UTF8&adId=A04325393GUQHXBBKQ9B5&url=%2FPIQIDIG-Hiking-Shorts-Pockets-Camouflage%2Fdp%2FB09671GGYZ%2Fref%3Dsr_1_78_sspa%3Fkeywords%3Dshirt%26qid%3D1643967718%26sr%3D8-78-spons%26psc%3D1&qualifier=1643967718&id=1350871726496264&widgetName=sp_mtf
# Mens Shorts Casual Relaxed Fit Classic Cargo Shorts Golf Hiking Fishing Big and Tall Shorts with Multiple Pockets
# 4.4 out of 5 stars | 45
# $25.99 | (None)
# --------------------------------------------------
# https://www.amazon.com/Hanes-Womens-Pique-Forest-Medium/dp/B071CNBXPB/ref=sr_1_206?keywords=shirt&qid=1643967726&sr=8-206
# Hanes Women's X-Temp Polo with FreshIQ
# 4.1 out of 5 stars | 6,286
# $14.00 | (None)
# --------------------------------------------------
# https://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_mtf
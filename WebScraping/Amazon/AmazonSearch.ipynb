# %%
import amazonwebscrape as scraper

# %%
KEYWORD = "gpu"
TOTAL_PAGES = 10

# %%
scraper.search_web_scraping(KEYWORD, TOTAL_PAGES)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Page: 1 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 2 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 3 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 4 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 5 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 6 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 7 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 8 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 9 | Success | Saved file 'AmazonSearch_gpu.json'
# Page: 10 | Success | Saved file 'AmazonSearch_gpu.json'
# Total data: 224

# %%
data = scraper.load_json(f'AmazonSearch_{KEYWORD}.json')
len(data)
# Out:
# 224

# %%
scraper.show_search_results(data, 10)
# Out:
# https://www.amazon.com/XFX-Radeon-1386MHz-Graphics-RX-580P8DFD6/dp/B06Y66K3XD/ref=sr_1_45?keywords=gpu&qid=1644638321&sr=8-45
# XFX Radeon RX 580 GTS XXX Edition 1386MHz OC+, 8GB GDDR5, VR Ready, Dual BIOS, 3xDP HDMI DVI, AMD Graphics Card (RX-580P8DFD6)
# 4.5 out of 5 stars | 6,955
# None | (None)
# --------------------------------------------------
# https://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_btf_aps_sr_pg4_1?ie=UTF8&adId=A0471687HW6S4Z8PCRWX&url=%2FAmangny-Female-Express-Adapter-Sleeved%2Fdp%2FB096B31KQG%2Fref%3Dsr_1_70_sspa%3Fkeywords%3Dgpu%26qid%3D1644638325%26sr%3D8-70-spons%26psc%3D1&qualifier=1644638325&id=328049239757262&widgetName=sp_btf
# Amangny GPU PCIe 6 Pin Female to 2 X 8(6+2) Pin Male PCI Express Adapter Sleeved Power Cable 9 inch (3 Pack)
# 4.7 out of 5 stars | 4
# $12.99 | (None)
# --------------------------------------------------
# https://www.amazon.com/ZOTAC-GTX-1660-Graphics-ZT-T16620F-10L/dp/B07Z8PWC6R/ref=sr_1_8?keywords=gpu&qid=1644638312&sr=8-8
# ZOTAC Gaming GeForce GTX 1660 Super 6GB GDDR6 192-bit Gaming Graphics Card, Super Compact, ZT-T16620F-10L
# 4.7 out of 5 stars | 1,906
# $519.99 | (None)
# --------------------------------------------------
# https://www.amazon.com/XFX-Speedster-Radeon-Graphics-RX-66XL8LFDQ/dp/B09HHLX543/ref=sr_1_119?keywords=gpu&qid=1644638340&sr=8-119
# XFX Speedster SWFT 210 Radeon RX 6600 CORE Gaming Graphics Card with 8GB GDDR6 HDMI 3xDP, AMD RDNA 2 RX-66XL8LFDQ
# 4.7 out of 5 stars | 64
# $540.89 | (None)
# --------------------------------------------------
# https://www.amazon.com/Sapphire-Technology-Radeon-Graphics-11310-01-20G/dp/B09JHRQY4Y/ref=sr_1_126?keywords=gpu&qid=1644638340&sr=8-126
# Sapphire Technology Pulse AMD Radeon RX 6600 Gaming Graphics Card with 8GB GDDR6, AMD RDNA 2, (11310-01-20G)
# 4.4 out of 5 stars | 33
# None | (None)
# --------------------------------------------------
# https://www.amazon.com/CloverTale-Aerospace-Upgraded-Version-Black/dp/B077LGLN4G/ref=sr_1_157?keywords=gpu&qid=1644638348&sr=8-157
# CloverTale Graphics Card GPU Brace Support, Video Card Sag Holder Bracket, Anodized Aerospace Aluminum (Upgraded Version Black)
# 4.3 out of 5 stars | 1,703
# $9.99 | (None)
# --------------------------------------------------
# https://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_btf_aps_sr_pg4_1?ie=UTF8&adId=A04754863HNN17YPX36V9&url=%2FAmangny-Express-Adapter-Braided-Splitter%2Fdp%2FB094QSRK98%2Fref%3Dsr_1_69_sspa%3Fkeywords%3Dgpu%26qid%3D1644638325%26sr%3D8-69-spons%26psc%3D1%26smid%3DA2K1N4NSXHNIZJ&qualifier=1644638325&id=328049239757262&widgetName=sp_btf
# Amangny GPU VGA PCI-e 8 Pin Female to Dual 8(6+2) Pin Male PCI Express Adapter Braided Sleeved Splitter Power Cable 9 inch (6 Pack)
# 4.8 out of 5 stars | 61
# $30.47 | ($32.99)
# --------------------------------------------------
# https://www.amazon.com/GIGABYTE-Graphics-WINDFORCE-Cooling-GV-R66EAGLE-8GD/dp/B09J2NCD2L/ref=sr_1_71?keywords=gpu&qid=1644638328&sr=8-71
# GIGABYTE Radeon RX 6600 Eagle 8G Graphics Card, WINDFORCE 3X Cooling System, 8GB 128-bit GDDR6, GV-R66EAGLE-8GD Video Card
# 4.9 out of 5 stars | 23
# $597.99 | (None)
# --------------------------------------------------
# https://www.amazon.com/ASUS-ROG-STRIX-GTX1080TI-O11G-GAMING-DisplayPort-Overclocked-Refurbished/dp/B07JZKT6NJ/ref=sr_1_57?keywords=gpu&qid=1644638325&sr=8-57
# ASUS ROG-STRIX-GTX1080TI-O11G-GAMING GeForce 11GB OC Edition VR Ready 5K HD Gaming HDMI DisplayPort DVI Overclocked PC GDDR5X Graphics Card (Renewed)
# 4.5 out of 5 stars | 22
# $899.99 | ($1,078.10)
# --------------------------------------------------
# https://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_btf_aps_sr_pg3_1?ie=UTF8&adId=A01189773RHP35AUIZGAD&url=%2FKAER-Graphics-Express-DirectX-Desktop%2Fdp%2FB09GF7PGCF%2Fref%3Dsr_1_54_sspa%3Fkeywords%3Dgpu%26qid%3D1644638321%26sr%3D8-54-spons%26psc%3D1&qualifier=1644638321&id=2502609198249424&widgetName=sp_btf
# KAER GT 1030 Graphics Card, 2GB, 64 Bit, GDDR5, VGA/HDMI, PCI Express 3.0 x4, DirectX 12, 4K, Nvidia GPU, Desktop Gaming Video Card
# 4.1 out of 5 stars | 23
# $149.99 | (None)
# --------------------------------------------------

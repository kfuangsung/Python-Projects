# %%
import amazonwebscrape as scraper

# %%
KEYWORD = "headphone"
TOTAL_PAGES = 10

# %%
scraper.search_web_scraping(KEYWORD, TOTAL_PAGES)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Page: 1 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 2 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 3 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 4 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 5 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 6 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 7 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 8 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 9 | Success | Saved file 'AmazonSearch_headphone.json'
# Page: 10 | Success | Saved file 'AmazonSearch_headphone.json'
# Total data: 230

# %%
data = scraper.load_json(f'AmazonSearch_{KEYWORD}.json')
len(data)
# Out:
# 230

# %%
scraper.show_search_results(data, 10)
# Out:
# https://www.amazon.com/Sony-MDR7506-Professional-Diaphragm-Headphone/dp/B000AJIF4E/ref=sr_1_67?keywords=headphones&qid=1646798050&sr=8-67
# Sony MDR7506 Professional Large Diaphragm Headphone
# 4.8 out of 5 stars | 17,717
# $96.00 | (None)
# --------------------------------------------------
# https://www.amazon.com/beyerdynamic-770-PRO-Studio-Headphone/dp/B0016MNAAI/ref=sr_1_42?keywords=headphones&qid=1646798046&sr=8-42
# beyerdynamic DT 770 PRO 80 Ohm Over-Ear Studio Headphones in Gray. Enclosed design, wired for professional recording and monitoring
# 4.7 out of 5 stars | 18,107
# $157.00 | ($299.00)
# --------------------------------------------------
# https://www.amazon.com/Small-Bluetooth-Headphones-Wrap-Around/dp/B09BQ31GYW/ref=sr_1_99?keywords=headphones&qid=1646798060&sr=8-99
# Small Bluetooth Headphones Wrap Around Head - Sports Wireless Headset with Built in Microphone and Crystal-Clear Sound, Foldable and Carried in The Purse, and 12-Hour Battery Life, Blue
# ...
